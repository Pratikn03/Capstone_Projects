# %% [markdown]
# # 01 — EDA (OPSD Germany)
#
# GridPulse notebook starter.

# %% [markdown]
# ## Load data
# This reads the OPSD hourly file and inspects key columns (load/wind/solar).

# %%
import pandas as pd
from pathlib import Path

raw = Path("../data/raw/time_series_60min_singleindex.csv")
raw.exists(), raw

# %%
cols = ["utc_timestamp","DE_load_actual_entsoe_transparency","DE_wind_generation_actual","DE_solar_generation_actual"]
df = pd.read_csv(raw, usecols=lambda c: c in cols)
df.head()

# %%
df["utc_timestamp"] = pd.to_datetime(df["utc_timestamp"], utc=True)
df = df.sort_values("utc_timestamp")
df.describe()

# %% [markdown]
# ## Quick plots

# %%
import matplotlib.pyplot as plt

df_small = df.tail(24*14)  # last 14 days
plt.figure()
plt.plot(df_small["utc_timestamp"], df_small["DE_load_actual_entsoe_transparency"])
plt.title("Load (last 14 days)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
