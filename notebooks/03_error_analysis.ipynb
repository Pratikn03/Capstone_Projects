# %% [markdown]
# # 03 — Error Analysis (Seasonality + Peaks)
#
# GridPulse notebook starter.

# %% [markdown]
# ## Load saved metrics and extend analysis
# Add seasonal buckets and peak-hour evaluation.

# %%
import json
import pandas as pd
from pathlib import Path

metrics = json.loads(Path("../artifacts/backtests/week1_baseline_load_mw.json").read_text())
metrics

# %% [markdown]
# ## TODO
# - Bucket by month/season
# - Evaluate peak hours only
# - Add worst-case day analysis
