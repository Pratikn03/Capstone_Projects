# %% [markdown]
# # Train Models

# %% [markdown]
# Train GBM/LSTM/TCN models and write comparison report.

# %%
import sys, subprocess
from pathlib import Path

print("Python:", sys.executable)
repo_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
subprocess.run(["pip", "install", "-e", str(repo_root)], check=True)
# Out:
# Python: /Users/pratik_n/Downloads/gridpulse/.venv/bin/python
# Obtaining file:///Users/pratik_n/Downloads/gridpulse
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: gridpulse
#   Building editable for gridpulse (pyproject.toml): started
#   Building editable for gridpulse (pyproject.toml): finished with status 'done'
#   Created wheel for gridpulse: filename=gridpulse-0.1.0-0.editable-py3-none-any.whl size=6066 sha256=a1dd7deec0e2adff0fad1edf5f9afde9b9a96fbb563bfdb08a0ad61374eb1182
#   Stored in directory: /private/var/folders/pk/ksqc41pj60q3589gfwhqz5tw0000gn/T/pip-ephem-wheel-cache-kzf1i0tc/wheels/8a/44/a7/bd98a379fbc961575d40cd445a0126607882e02e2add1974f3
# Successfully built gridpulse
# Installing collected packages: gridpulse
#   Attempting uninstall: gridpulse
#     Found existing installation: gridpulse 0.1.0
#     Uninstalling gridpulse-0.1.0:
#       Successfully uninstalled gridpulse-0.1.0
# Successfully installed gridpulse-0.1.0
# CompletedProcess(args=['pip', 'install', '-e', '/Users/pratik_n/Downloads/gridpulse'], returncode=0)

# %%
from pathlib import Path
print("Repo root:", repo_root)
# Out:
# Repo root: /Users/pratik_n/Downloads/gridpulse

# %%
import subprocess

subprocess.run([
    "python", "-m", "gridpulse.forecasting.train",
    "--config", "configs/train_forecast.yaml"
], check=True, cwd=str(repo_root))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001348 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6942
# [LightGBM] [Info] Number of data points in the train set: 34636, number of used features: 35
# [LightGBM] [Info] Start training from score 55871.776706
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Epoch 1/10 train_mse=3222166507.1407 val_mse=3168190808.2759
# Epoch 2/10 train_mse=3220041839.8815 val_mse=3166174984.8276
# Epoch 3/10 train_mse=3218036878.2222 val_mse=3164202407.7241
# Epoch 4/10 train_mse=3216059340.8000 val_mse=3162247070.8966
# Epoch 5/10 train_mse=3214094609.0667 val_mse=3160301056.0000
# Epoch 6/10 train_mse=3212137618.0148 val_mse=3158361352.8276
# Epoch 7/10 train_mse=3210185870.2222 val_mse=3156426054.6207
# Epoch 8/10 train_mse=3208238034.4889 val_mse=3154494128.5517
# Epoch 9/10 train_mse=3206293174.0444 val_mse=3152564939.0345
# Epoch 10/10 train_mse=3204350833.7778 val_mse=3150637965.2414
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Epoch 1/10 train_mse=224054540.7704 val_mse=78339002.8966
# Epoch 2/10 train_mse=61806363.2296 val_mse=104699592.8966
# Epoch 3/10 train_mse=51179207.8963 val_mse=171024454.8276
# Epoch 4/10 train_mse=47375389.1852 val_mse=282021945.2414
# Epoch 5/10 train_mse=51630595.5111 val_mse=442003395.1724
# Epoch 6/10 train_mse=81435534.1333 val_mse=541004923.3103
# Epoch 7/10 train_mse=92045800.5778 val_mse=51083672.9655
# Epoch 8/10 train_mse=53751939.0963 val_mse=50372555.5172
# Epoch 9/10 train_mse=48695319.5407 val_mse=46297397.4483
# Epoch 10/10 train_mse=45226945.6593 val_mse=47172305.7241
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001074 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6942
# [LightGBM] [Info] Number of data points in the train set: 34636, number of used features: 35
# [LightGBM] [Info] Start training from score 10602.222980
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Epoch 1/10 train_mse=182344247.9037 val_mse=243826942.0000
# Epoch 2/10 train_mse=181975348.8593 val_mse=243407798.9655
# Epoch 3/10 train_mse=181633446.1704 val_mse=242999889.5862
# Epoch 4/10 train_mse=181297700.8000 val_mse=242596864.8966
# Epoch 5/10 train_mse=180965156.7630 val_mse=242196796.8966
# Epoch 6/10 train_mse=180634758.6148 val_mse=241798852.2069
# Epoch 7/10 train_mse=180305997.8222 val_mse=241402580.6207
# Epoch 8/10 train_mse=179978582.8370 val_mse=241007720.8966
# Epoch 9/10 train_mse=179652337.8889 val_mse=240614085.2414
# Epoch 10/10 train_mse=179327142.6889 val_mse=240221550.1379
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Epoch 1/10 train_mse=65831554.9259 val_mse=66349362.6897
# Epoch 2/10 train_mse=52857093.8593 val_mse=56734842.7586
# Epoch 3/10 train_mse=47926069.0407 val_mse=55467401.1724
# Epoch 4/10 train_mse=46583175.1556 val_mse=54865293.0000
# Epoch 5/10 train_mse=45854113.1370 val_mse=54606651.4828
# Epoch 6/10 train_mse=45310760.9370 val_mse=54411009.6552
# Epoch 7/10 train_mse=44919790.1741 val_mse=54329632.4138
# Epoch 8/10 train_mse=44618268.5667 val_mse=54353378.2759
# Epoch 9/10 train_mse=44433146.8667 val_mse=54375250.3448
# Epoch 10/10 train_mse=44244373.9704 val_mse=54391375.3103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001104 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6942
# [LightGBM] [Info] Number of data points in the train set: 34636, number of used features: 35
# [LightGBM] [Info] Start training from score 4168.066174
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# Epoch 1/10 train_mse=58554317.1366 val_mse=88382778.6552
# Epoch 2/10 train_mse=58415851.6394 val_mse=88212539.5000
# Epoch 3/10 train_mse=58287624.3458 val_mse=88047041.0517
# Epoch 4/10 train_mse=58162026.4639 val_mse=87883857.1897
# Epoch 5/10 train_mse=58037992.1421 val_mse=87722253.4655
# Epoch 6/10 train_mse=57915139.1116 val_mse=87561905.9828
# Epoch 7/10 train_mse=57793282.9264 val_mse=87402643.1207
# Epoch 8/10 train_mse=57672315.0653 val_mse=87244362.6724
# Epoch 9/10 train_mse=57552167.9366 val_mse=87086978.6724
# Epoch 10/10 train_mse=57432794.0458 val_mse=86930450.7414
# /Users/pratik_n/Downloads/gridpulse/.venv/lib/python3.9/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Epoch 1/10 train_mse=13896964.5019 val_mse=82831568.5862
# Epoch 2/10 train_mse=14728275.1454 val_mse=12176660.8362
# Epoch 3/10 train_mse=6411528.2458 val_mse=9021965.6250
# Epoch 4/10 train_mse=5283238.7509 val_mse=9070942.8966
# Epoch 5/10 train_mse=5113939.0116 val_mse=8828098.4828
# Epoch 6/10 train_mse=4956202.1701 val_mse=8574765.9741
# Epoch 7/10 train_mse=4850584.7303 val_mse=8314093.8578
# Epoch 8/10 train_mse=4740333.9414 val_mse=8292781.9267
# Epoch 9/10 train_mse=4700443.8576 val_mse=8013996.5172
# Epoch 10/10 train_mse=4611725.4715 val_mse=8038471.9009
# Saved report to reports/ and models to artifacts/models
# CompletedProcess(args=['python', '-m', 'gridpulse.forecasting.train', '--config', 'configs/train_forecast.yaml'], returncode=0)

# %%
from pathlib import Path

report_path = Path(repo_root) / "reports" / "ml_vs_dl_comparison.md"
print("Report path:", report_path)

if report_path.exists():
    print(report_path.read_text()[:1000])
else:
    print("Report not found. Make sure the training cell finished successfully.")
# Out:
# Report path: /Users/pratik_n/Downloads/gridpulse/reports/ml_vs_dl_comparison.md
# # ML vs DL Comparison
#
# ## Setup
# - Targets: **load_mw, wind_mw, solar_mw**
# - Device: **cpu**
# - Quantiles: **[0.1, 0.5, 0.9]**
#
# ## Target: load_mw
#
# | Model | RMSE | MAPE |
# |---|---:|---:|
# | gbm_lightgbm | 210.058 | 0.003 |
# | lstm | 53976.906 | 0.997 |
# | tcn | 6643.542 | 0.107 |
#
# ## Target: wind_mw
#
# | Model | RMSE | MAPE |
# |---|---:|---:|
# | gbm_lightgbm | 457.336 | 0.009 |
# | lstm | 18422.062 | 0.974 |
# | tcn | 8307.022 | 0.872 |
#
# ## Target: solar_mw
#
# | Model | RMSE | MAPE |
# |---|---:|---:|
# | gbm_lightgbm | 442.729 | 42096950.320 |
# | lstm | 10155.833 | 6234659840.000 |
# | tcn | 2949.849 | 34253938688.000 |
